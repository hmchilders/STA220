# %% [markdown]
# ##### STA 220 Data & Web Technologies for Data Analysis
#
# ### Lecture 4, 1/15/26, Concurrency

# %% [markdown]
# ### Today's Topics
#
#  - Concurrency
#      - Threads and Processes
#      - I/O-Concurrency
#          - `threading`
#      - CPU-Concurrency (Parallelization)
#          - `multiprocessing`
#          - `Spark`
#
# ### References
# - [SuperFastPython](https://superfastpython.com/thread-vs-process/) by Jason Brownlee
# - [An introduction to parallel programming](https://sebastianraschka.com/Articles/2014_multiprocessing.html) by Sebastian Raschka
# - [Speed Up Your Python Program With Concurrency](https://realpython.com/python-concurrency/) by Jim Anderson
# - [An Intro to Threading in Python](https://realpython.com/intro-to-python-threading/) by Jim Anderson
# - [Parallelization in Python](https://towardsdatascience.com/3-methods-for-parallelization-in-spark-6a1a4333b473) by Ben Weber

# %% [markdown]
# ### Announcements
#
# - First homework will be assigned soon

# %% [markdown]
# ### Discussion
#
# The discussion sections take place after Thursday's lecture, 3:20 - 4:00 PM, at the Olson Hall 251.
#
# This week's topics are:
# - Regular expressions

# %% [markdown]
# ### Threads and Processes
#
# A computer can have multiple CPUs, each CPU has multiple cores (e.g., two quad-core CPUs).
# All the CPUs are connected to memory (e.g., 64G memory).
# CPU cores can execute in parallel.
#
# <div>
# <img src="../images/fig1.png" alt="Drawing" style="width: 1000px;"/>
# </div>

# %% [markdown]
# A __process__ is the *operating system’s spawned and controlled entity that encapsulates an executing application* ([Breshears: The Art of Concurrency](https://amzn.to/3J74TRr)).
#
# A __thread__ is a path of execution which belongs to a process.
#
# Each thread belongs to a process. In single-threaded processes, the process contains one thread. In multithreaded processes, the process contains more than one thread, and the process is accomplishing a number of things at the same time.

# %% [markdown]
# Threads can share memory within a process. This means that functions executed in new threads can access the same data and state. These might be global variables or data shared via function arguments. As such, sharing state between threads is straightforward.
#
# Threads are sometimes called lightweight processes because they have their own stack but can access shared data.
#
# <div>
# <img src="../images/fig3.png" alt="Drawing" style="width: 800px;"/>
# </div>

# %% [markdown]
# On the other hand, processes are 'share nothing', i.e., they independently execute without sharing memory or state. This makes it easier to turn into a distributed application, but typically, sharing data between processes requires explicit mechanisms.
#
# <div>
# <img src="../images/fig4.png" alt="Drawing" style="width: 800px;"/>
# </div>

# %% [markdown]
# Python allows to execute code using the principle of global interpreter lock (GIL). This means that only one thread can be executed at a time. This simplifies implementation, but makes it more difficult to execute code concurrently.
#
# Today, we will explore the advantages of executing multiple processes and threads and discuss under what circumstances which approach is most adequate.

# %% [markdown]
# There are two major kind of tasks, that will slow down your program: CPU-bound and I/O-bound.
#
# I/O-bound tasks cause your program to slow down because it frequently must wait for input/output (I/O) from some external resource. They arise when your program interacts with other sources, i.e., when your are *requesting* data from another source.

# %% [markdown]
# <div>
# <img src=https://files.realpython.com/media/IOBound.4810a888b457.png style="width: 1500px;"/>
# </div>

# %% [markdown]
# CPU-bound tasks are those that require a lot of *computational* effort to complete.

# %% [markdown]
# <div>
# <img src=https://files.realpython.com/media/CPUBound.d2d32cb2626c.png style="width: 1700px;"/>
# </div>

# %% [markdown]
# We will use threads and the module `threading` for I/O-bound tasks and processes and the module `multiprocessing` for CPU-bound tasks.

# %% [markdown]
# - CPU: 100_000_000_000 instructions per second (Intel i7)
# - 10_000_000 memory references per second
# - 500 disc seeks per second
# - 7 pings from US to Europe (and back) per second
#
# Thus, if you are waiting for a disc seek to complete or for data from the web, you could do a LOT of calculations in between.

# %% [markdown]
# ### I/O-Concurrency
#
# We’ll start with a non-concurrent version of this a I/O-bound task. Namely, we will use `requests` to request data from a [website](https://homepage.univie.ac.at/nicolai.amann/). For `request.Session`, see [here](https://requests.readthedocs.io/en/latest/user/advanced/) and [docs](https://requests.readthedocs.io/en/latest/api/?#requests.Session).

# %%
import requests, time

def download_site(url, session):
    session.get(url) # fetch information from url 
    # ... do something ... 
    
def download_all_sites(sites):
    session = requests.Session()
    [download_site(url, session) for url in sites]
        
def task(): 
    sites = ["https://homepage.univie.ac.at/nicolai.amann/"] * 20
    start_time = time.time()
    download_all_sites(sites)
    print(time.time() - start_time)

# %%
task()
# Out:
# 6.990546941757202

# %% [markdown]
# We will now use concurrent threads that accomplish the same task, retrieving information by executing `requests.get` more efficient.

# %%
import concurrent.futures, threading

def download_site(url, session):
    session.get(url) # fetch information from url 
    # ... do something ... 
    
def download_all_sites(sites):
    session = requests.Session()
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
        executor.map(lambda u: download_site(u, session), sites)
        
def task(): 
    sites = ["https://homepage.univie.ac.at/nicolai.amann/"] * 10
    start_time = time.time()
    download_all_sites(sites)
    print(time.time() - start_time)

# %%
task()
# Out:
# 0.7973179817199707

# %%
import concurrent.futures, threading

thread_local = threading.local() # instantiates thread to create local data (here: session-attr.)

def download_site(url):
    session = get_session()
    session.get(url)
    # ... do something ... 

def download_all_sites(sites):
    with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
        executor.map(download_site, sites)

def get_session():
    '''Create a new requests.Session if there is none in thread_local'''
    if not hasattr(thread_local, "session"): 
        thread_local.session = requests.Session()
    return thread_local.session

# %% [markdown]
# We have created a `concurrent.futures.ThreadPoolExecutor`. It creates four threads that are run concurrently.
#
# Also, each thread will become its own separate `requests.Session`. This is one of the interesting and difficult issues with threading. Because the operating system is in control of switching between threads, any data that is shared between the threads needs to be protected, or thread-safe. Unfortunately `requests.Session` is not thread-safe. If untreated, *race conditions* can produce hard-to-detect bugs.
#
# Here, we use `threading.local()` to instantiate an object that looks like a global but is specific to each individual thread.

# %%
task()
# Out:
# 1.1452770233154297

# %% [markdown]
# The code above is faster than the non-concurrent version, because the I/O-bound has been circumvented.

# %% [markdown]
# <div>
# <img src=https://files.realpython.com/media/Threading.3eef48da829e.png style="width: 900px;"/>
# </div>

# %% [markdown]
# ### CPU-Concurrency (Parallelization)
#
# The above example of concurrency run only on a single CPU. This is due to the GIL. The `multiprocessing` module breaks down that barrier and runs code across multiple CPUs.
#
# It does this by creating a new instance of the Python interpreter (a new process) to run on each CPU and then farming out part of your program to run on it.  Bringing up a separate Python interpreter is not as fast as starting a new thread in the current Python interpreter. Regarding `.set_start_method`, see [here](https://docs.python.org/3/library/multiprocessing.html#contexts-and-start-methods).

# %%
import multiprocessing

multiprocessing.cpu_count() # number of cores on laptop/computer
# Out:
# 8

# %%
session = None
multiprocessing.set_start_method("fork") # new process will be a copy from previous process

def set_global_session():
    global session
    if not session:
        session = requests.Session()

def download_site(url):
    session.get(url)
    # ... do something ... 

def download_all_sites(sites):
    with multiprocessing.Pool(initializer=set_global_session, processes = 8) as pool: # change processes!
        pool.map(download_site, sites)

def task(): 
    sites = ["https://homepage.univie.ac.at/nicolai.amann/"] * 10
    start_time = time.time()
    download_all_sites(sites)
    print(time.time() - start_time)

task()

# %% [markdown]
# We may even be faster than with `threading`, since we are running up to 8 processes in parallel, but `multiprocessing` cannot scale beyond the number of cores in your local machine.
# The default argument `processes` of `multiprocessing.pool.Pool` ([docs](https://docs.python.org/3/library/multiprocessing.html?#module-multiprocessing.pool)), is the number of available cores on the machine.
#
# Remember that each process has its own memory space (share-nothing). That means that they cannot share things like a `requests.Session` object. We don’t want to create a new Session each time the function is called, you want to create one for each process, which calls `request.get` multiple times after another.
#
# The `initializer` function parameter is built for just this case. We initialize a global `session` variable to hold the single `requests.Session` *for each process*. Because each process has its own memory space, the global for each one will be different.

# %% [markdown]
# <div>
# <img src=https://files.realpython.com/media/MProc.7cf3be371bbc.png style="height: 500px;"/>
# </div>

# %% [markdown]
# This course will deal with fetching information from the web, usually via requests. While these requests will usually be bound by third partys who maintain the servers we are requesting from as well, they are in essence I/O-bound task. `multiprocessing` however is useful for CPU-bound tasks. Consequently, lets consider a computational problem.

# %% [markdown]
# For the purposes of our example, we’ll use a somewhat silly function to create something that takes a long time to run on the CPU. This function computes the sum of the squares of each number from 0 to the passed-in value:

# %%
def problem(number):
    return sum(i * i for i in range(number))

def find_sums(numbers):
    for number in numbers:
        problem(number)

def task():
    numbers = [5_000_000 + x for x in range(20)]
    start_time = time.time()
    find_sums(numbers)
    print(time.time() - start_time)

# %%
task()
# Out:
# 3.062579870223999

# %% [markdown]
# This code calls `problem` 20 times with a different large number each time. It does all of this on a single thread in a single process on a single CPU. The execution timing diagram looks like this:

# %% [markdown]
# <div>
# <img src=https://files.realpython.com/media/CPUBound.d2d32cb2626c.png style="width: 1600px;"/>
# </div>

# %% [markdown]
# Since there is no I/O waiting time, `threading` will not speed up this problem. We can however speed the computation by using our multiple cores.

# %%
# multiprocessing.set_start_method("fork", True) # has already been set
def find_sums(numbers):
    pool = multiprocessing.Pool(processes = 8)
    return pool.map(problem, numbers)

# %%
task()
# Out:
# 0.7028112411499023

# %%
def problem(number):
    return sum(i * i for i in range(number))

def find_sums(numbers):
    pool = multiprocessing.Pool(processes = 8)
    return pool.map(problem, numbers)

def task():
    numbers = [5_000_000 + x for x in range(20)]
    start_time = time.time()
    vl_numbers = find_sums(numbers)
    print(time.time() - start_time)
    print(vl_numbers)

# %%
task()
# Out:
# 0.6990382671356201
# [41666654166667500000, 41666679166667500000, 41666704166677500001, 41666729166697500005, 41666754166727500014, 41666779166767500030, 41666804166817500055, 41666829166877500091, 41666854166947500140, 41666879167027500204, 41666904167117500285, 41666929167217500385, 41666954167327500506, 41666979167447500650, 41667004167577500819, 41667029167717501015, 41667054167867501240, 41667079168027501496, 41667104168197501785, 41667129168377502109]

# %%
multiprocessing.cpu_count()
# Out:
# 8

# %% [markdown]
# This code is similar as for the I/O-bound problem, but here you don’t need to worry about the `requests.Session` object. Notably, the speed-up is not equal to the number of cores, as each process has to set up its own Python interpreter.

# %% [markdown]
# <div>
# <img src=https://files.realpython.com/media/CPUMP.69c1a7fad9c4.png style="height: 400px;"/>
# </div>

# %% [markdown]
# While this codes is easy and fast. All the single processes are automatically taken care of with `multiprocessing.Pool`. The results returned by `problem` are gathered by `multiprocessing.map` as a <kbd>list</kbd> type.

# %%
find_sums(range(0, 4)) # returns a list
# Out:
# [0, 0, 1, 5]

# %% [markdown]
# However, many solution require communication between the processes. This can add some complexity to your solution that a non-concurrent program would not need to deal with.

# %% [markdown]
# A `multiprocessing.Queue` object provides a mechanism to pass data between a parent process and the descendent processes of it. It adheres the *first in first out* principle. We can retrieve with the `multiprocessing.get` method and set with the `multiprocessing.put` method.
#
# <div>
# <img src=https://media.geeksforgeeks.org/wp-content/uploads/multiprocessing-python-4.png style="width: 700px;"/>
# </div>

# %%
q = multiprocessing.Queue()
def myfun(q, i): 
    q.put(i)

# %%
q.empty()
# Out:
# True

# %%
# initialize process
processes = [multiprocessing.Process(target=myfun, args = (q, i)) for i in range(4)]
processes
# Out:
# [<Process name='Process-44' parent=1029 initial>,
#  <Process name='Process-45' parent=1029 initial>,
#  <Process name='Process-46' parent=1029 initial>,
#  <Process name='Process-47' parent=1029 initial>]

# %% [markdown]
# Report snapshot of the current processes number 33 (without the keyword grep).

# %%
# !ps aux | grep "[5]44"
# Out:
# nicolai           2151   0.0  0.1 410854464  24320   ??  Ss    8:50AM   0:00.05 /System/Library/Frameworks/AppKit.framework/Versions/C/XPCServices/ThemeWidgetControlViewService.xpc/Contents/MacOS/ThemeWidgetControlViewService
# nicolai           2134   0.0  0.1 410954448  20176   ??  S     8:50AM   0:00.12 /usr/libexec/mlhostd
# nicolai            698   0.0  0.0 410172544   2816   ??  Ss    6:20AM   0:00.00 /System/Library/Frameworks/NetFS.framework/Versions/A/XPCServices/PlugInLibraryService.xpc/Contents/MacOS/PlugInLibraryService
# nicolai            587   0.0  0.0 410075440   1024   ??  S     6:20AM   0:00.00 /Applications/Firefox.app/Contents/MacOS/crashhelper 461 gecko-crash-server-pipe.461 /private/var/folders/qz/ztp_k9054wz3wyfvjqbw10_h0000gp/T/TemporaryItems/ 10
# root               544   0.0  0.1 410387728  19216   ??  Ss    6:20AM   0:00.35 /System/Library/PrivateFrameworks/AppSSO.framework/Support/AppSSODaemon
# root               401   0.0  0.1 410298544  10944   ??  Ss    6:20AM   0:00.05 /System/Library/Frameworks/GSS.framework/Helpers/GSSCred
# root               350   0.0  0.1 410330736   8544   ??  Ss    6:20AM   0:00.03 /System/Library/Frameworks/CryptoTokenKit.framework/ctkahp.bundle/Contents/MacOS/ctkahp -d
# _locationd         264   0.0  0.1 410375440  15600   ??  S     6:20AM   0:02.61 /usr/libexec/secinitd
# root               248   0.0  0.1 410365440  14624   ??  Ss    6:20AM   0:00.32 /System/Library/Frameworks/Security.framework/Versions/A/XPCServices/authd.xpc/Contents/MacOS/authd
# root                 1   0.0  0.1 411054464  23808   ??  Ss    6:20AM   0:13.49 /sbin/launchd

# %% [markdown]
# The processess are initialized but not yet executed.

# %%
# run processes
for process in processes:
    process.start()

# %%
# join processes
for process in processes:
    process.join()

# %% [markdown]
# The main purpose of `multiprocessing.join` ([docs](https://docs.python.org/3/library/multiprocessing.html?#multiprocessing.Process.join)) is to ensure that a child process has completed before the main process does anything that depends on the work of the child process.

# %%
processes
# Out:
# [<Process name='Process-44' pid=3708 parent=1029 stopped exitcode=0>,
#  <Process name='Process-45' pid=3709 parent=1029 stopped exitcode=0>,
#  <Process name='Process-46' pid=3710 parent=1029 stopped exitcode=0>,
#  <Process name='Process-47' pid=3711 parent=1029 stopped exitcode=0>]

# %% [markdown]
# The value `exitcode=0` means that the process has been completed successfully, without error ([docs](https://docs.python.org/3/library/multiprocessing.html?#multiprocessing.Process.exitcode)).

# %%
q.empty()
# Out:
# False

# %%
[q.get() for process in processes]
# Out:
# [0, 1, 2, 3]

# %%
q.empty()
# Out:
# True

# %% [markdown]
# While `multiprocessing` allows you to steer the processes directly, many statistical problems are already implemented and ready for parallel computing, e.g. via `Spark`.

# %%
from multiprocessing import Process, Queue
import time

def producer(q, items_to_produce):
    for i in range(items_to_produce):
        item = f"Item {i}"
        print(f"Producer: Putting {item}")
        q.put(item)
        time.sleep(0.1) # Simulate work
    q.put(None)

def consumer(q):
    while True:
        item = q.get()
        if item is None: # Check for sentinel value
            break
        print(f"Consumer: Got {item}")
        time.sleep(0.2) # Simulate work

queue = Queue()
    
p1 = Process(target=producer, args=(queue, 5))
c1 = Process(target=consumer, args=(queue,))

p1.start()
c1.start()

p1.join()
c1.join()

if queue.empty():
    print("Main: All processes finished.")
# Out:
# Producer: Putting Item 0
# Consumer: Got Item 0
# Producer: Putting Item 1
# Producer: Putting Item 2Consumer: Got Item 1
#
# Producer: Putting Item 3
# Consumer: Got Item 2
# Producer: Putting Item 4
# Consumer: Got Item 3
# Consumer: Got Item 4
# Main: All processes finished.

# %% [markdown]
# ### Spark
#
# Apache Spark is a computational engine that works with huge sets of data by processing them in parallel and batch systems. Spark is written in Scala, and [PySpark](https://www.dominodatalab.com/data-science-dictionary/pyspark) was released to support the collaboration of Spark and Python.
#
# The key data type used in PySpark is the Spark dataframe. This object can be thought of as a table distributed across a cluster, and has functionality that is similar to dataframes in `pandas`. If you want to do distributed computation using `PySpark`, then you’ll need to perform operations on Spark dataframes and not other Python data types.
#
# Here we explore how to perform tasks using `PySpark`.

# %% [markdown]
# Note: Unfortunately, just pip installing PySpark may not be enough to use the following code. Sometimes the installed JavaScript version on your PC/laptop is not matching the requirement for PySpark.

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/anaconda3/lib/python3.13/site-packages (4.0.0)
# Requirement already satisfied: py4j==0.10.9.9 in /opt/anaconda3/lib/python3.13/site-packages (from pyspark) (0.10.9.9)

# %% [markdown]
# We consider a simple regression model for predicting house prices. Lets consider the non-serialized version first:

# %%
import numpy as np
import pandas as pd

# %%
# load the california housing data set
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# convert to a Pandas Data Frame
housing_pd = pd.DataFrame(data= np.c_[housing['data'],housing['target']], 
                          columns= np.append(housing['feature_names'], 'target')).sample(frac=1) 

# concatenate data
# get all the data (fraction of 1 = 100%)
# sample chooses without replacement: thus, we get a random ordering!

# %%
housing_pd.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5516   6.2673      38.0  5.516667   0.972222       374.0  2.077778     33.97
# 14286  3.3700      36.0  4.960130   1.045566      3093.0  2.516680     32.72
# 14791  2.5988      28.0  5.433140   1.183140      1074.0  3.122093     32.58
# 6092   3.1133      27.0  4.201923   0.968750       985.0  2.367788     34.11
# 3443   1.9500      19.0  3.218391   0.965517       483.0  5.551724     34.25
#
#        Longitude  target
# 5516     -118.39   3.572
# 14286    -117.12   1.591
# 14791    -117.11   1.356
# 6092     -117.85   1.806
# 3443     -118.41   1.375

# %% [markdown]
# California housing dataset.
#
# ThThis dataset was obtained from the StatLib repository. https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The data contains 20,640 observations on 9 variables.
#
# This dataset contains the average house value as target variable
# and the following input variables (features): media income,
# housing median age, average rooms, average bedrooms, population,
# average occupation, latitude, and longitude in that order.
#
# References:
#
# Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
# Statistics and Probability Letters, 33:291-297, 1997.

# %%
housing_pd.shape
# Out:
# (20640, 9)

# %%
housing_pd.head(5)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5516   6.2673      38.0  5.516667   0.972222       374.0  2.077778     33.97
# 14286  3.3700      36.0  4.960130   1.045566      3093.0  2.516680     32.72
# 14791  2.5988      28.0  5.433140   1.183140      1074.0  3.122093     32.58
# 6092   3.1133      27.0  4.201923   0.968750       985.0  2.367788     34.11
# 3443   1.9500      19.0  3.218391   0.965517       483.0  5.551724     34.25
#
#        Longitude  target
# 5516     -118.39   3.572
# 14286    -117.12   1.591
# 14791    -117.11   1.356
# 6092     -117.85   1.806
# 3443     -118.41   1.375

# %% [markdown]
# Attribute Information:
# - MedInc: median income in block group
# - HouseAge: median house age in block group
# - AveRooms: average number of rooms per household
# - AveBedrms: average number of bedrooms per household
# - Population: block group population
# - AveOccup: average number of household members
# - Latitude: block group latitude
# - Longitude: block group longitude
#
# The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household, these columns may take surprisingly <em>large values for block groups with few households and many empty houses, such as vacation resorts</em>.

# %%
housing_pd.index.dtype
# Out:
# dtype('int64')

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 4.0.0

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession

sc = SparkContext('local') # Create an instance of SparkContext. Only run locally, i.e., on this laptop
spark = SparkSession(sc) # allows to use PySpark for DB, dataframes, etc
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/16 10:02:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# convert to a Spark data frame
housing_sp = spark.createDataFrame(housing_pd) # convert to sparkDF

# %%
print(housing_sp)
# Out:
# DataFrame[MedInc: double, HouseAge: double, AveRooms: double, AveBedrms: double, Population: double, AveOccup: double, Latitude: double, Longitude: double, target: double]

# %%
features = housing_sp.schema.names[:] # define the features to be all the names above
target = features.pop() # remove the last one (the target), and define it as the target variable

# %%
# alternatively, we also could have used the following code
features = housing_sp.schema.names[:-1] # define the features to be all but the last one of the names above
target = housing_sp.schema.names[-1] # define the last feature to be the target

# %%
print(features)
print(target)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# target

# %%
# convert to vector representation for MLlib
assembler = VectorAssembler(inputCols=features, outputCol="features" ) # creates a vector consisting of all features. They are distinguished by their column name.
housing = assembler.transform(housing_sp).select('features', 'target') # creates a new dataframe consisting and selects the features and target variables

# %% [markdown]
# See [docs](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.ml.regression.LinearRegression.html).

# %%
# linear regresion with Spark
from pyspark.ml.regression import LinearRegression
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator

# %%
# linear regression with penalization
lr = LinearRegression(labelCol="target", featuresCol="features", 
                      elasticNetParam = 1.0, # lasso / l1-penalization
                      standardization = True, 
                      fitIntercept=True)

# %%
lrparamGrid = (ParamGridBuilder()
               .addGrid(lr.regParam, [0.001, 0.01, 0.1, 0.2, 0.5, 0.75, 1.0, 1.5, 2.0]) # the Lasso regularizationParameter can either be 0.001, 0.01, etc.
               .build())

# %%
# Evaluate model
lrevaluator = RegressionEvaluator(predictionCol="prediction", labelCol="target", metricName="mse")

# %%
# Create 10-fold CrossValidator
lrcv = CrossValidator(estimator = lr, # base ML algorithm to be trained and evaluated
                      estimatorParamMaps = lrparamGrid, # possible parameters
                      evaluator = lrevaluator, # defines the metric to be optimized
                      numFolds = 10) # number of folds

# %%
# Run cross validations
lrcvModel = lrcv.fit(housing)
# Out:
# 25/10/16 10:12:33 WARN TaskSetManager: Stage 0 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:34 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 25/10/16 10:12:34 WARN TaskSetManager: Stage 1 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:34 WARN TaskSetManager: Stage 2 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 3 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 4 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 5 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 6 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 7 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 8 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 9 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 10 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 11 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 12 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 13 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 14 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 15 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 16 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 17 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 18 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 19 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 20 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 21 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:35 WARN TaskSetManager: Stage 22 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 23 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 24 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 25 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 26 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 27 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 28 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 29 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 30 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 31 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 32 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 33 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 34 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 35 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 36 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 37 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 38 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 39 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 40 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 41 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 42 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 43 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 44 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 45 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:36 WARN TaskSetManager: Stage 46 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 47 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 48 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 49 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 50 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 51 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 52 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 53 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 54 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 55 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 56 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 57 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 58 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 59 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 60 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 61 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 62 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 63 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 64 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 65 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 66 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 67 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 68 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 69 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 70 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 71 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 72 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 73 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:37 WARN TaskSetManager: Stage 74 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 75 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 76 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 77 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 78 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 79 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 80 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 81 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 82 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 83 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 84 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 85 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 86 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 87 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 88 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 89 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 90 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 91 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 92 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 93 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 94 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 95 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 96 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 97 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 98 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 99 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 100 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 101 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 102 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 103 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 104 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:38 WARN TaskSetManager: Stage 105 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 106 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 107 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 108 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 109 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 110 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 111 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 112 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 113 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 114 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 115 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 116 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 117 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 118 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 119 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 120 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 121 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 122 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 123 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 124 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 125 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 126 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 127 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 128 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 129 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 130 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 131 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 132 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 133 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:39 WARN TaskSetManager: Stage 134 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 135 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 136 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 137 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 138 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 139 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 140 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 141 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 142 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 143 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 144 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 145 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 146 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 147 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 148 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 149 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 150 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 151 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 152 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 153 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 154 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 155 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 156 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 157 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 158 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 159 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 160 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 161 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 162 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 163 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 164 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:40 WARN TaskSetManager: Stage 165 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 166 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 167 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 168 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 169 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 170 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 171 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 172 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 173 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 174 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 175 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 176 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 177 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 178 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 179 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 180 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 181 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 182 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 183 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 184 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 185 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 186 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 187 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 188 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 189 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 190 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 191 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 192 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 193 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 194 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 195 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 196 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 197 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:41 WARN TaskSetManager: Stage 198 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 199 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 200 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 201 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 202 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 203 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 204 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 205 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 206 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 207 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 208 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 209 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 210 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 211 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 212 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 213 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 214 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 215 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 216 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 217 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 218 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 219 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 220 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 221 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 222 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 223 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 224 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 225 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 226 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 227 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 228 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 229 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 230 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 231 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:42 WARN TaskSetManager: Stage 232 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 233 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 234 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 235 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 236 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 237 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 238 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 239 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 240 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 241 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 242 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 243 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 244 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 245 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 246 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 247 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 248 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 249 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 250 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 251 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 252 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 253 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 254 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 255 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 256 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 257 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 258 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 259 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 260 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 261 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 262 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 263 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 264 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:43 WARN TaskSetManager: Stage 265 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:44 WARN TaskSetManager: Stage 266 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:44 WARN TaskSetManager: Stage 267 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:44 WARN TaskSetManager: Stage 268 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:44 WARN TaskSetManager: Stage 269 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:44 WARN TaskSetManager: Stage 270 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.
# 25/10/16 10:12:44 WARN TaskSetManager: Stage 271 contains a task of very large size (1703 KiB). The maximum recommended task size is 1000 KiB.

# %% [markdown]
# See [docs](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.ml.regression.LinearRegressionTrainingSummary.html).

# %%
# Get Model Summary Statistics
lrcvSummary = lrcvModel.bestModel.summary
lrcvSummary.meanSquaredError
# Out:
# 0.5243769901637115

# %%
print(lrcvModel.bestModel.extractParamMap())
# Out:
# {Param(parent='LinearRegression_529bb0ad1e5e', name='aggregationDepth', doc='suggested depth for treeAggregate (>= 2).'): 2, Param(parent='LinearRegression_529bb0ad1e5e', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.'): 1.0, Param(parent='LinearRegression_529bb0ad1e5e', name='epsilon', doc='The shape parameter to control the amount of robustness. Must be > 1.0. Only valid when loss is huber'): 1.35, Param(parent='LinearRegression_529bb0ad1e5e', name='featuresCol', doc='features column name.'): 'features', Param(parent='LinearRegression_529bb0ad1e5e', name='fitIntercept', doc='whether to fit an intercept term.'): True, Param(parent='LinearRegression_529bb0ad1e5e', name='labelCol', doc='label column name.'): 'target', Param(parent='LinearRegression_529bb0ad1e5e', name='loss', doc='The loss function to be optimized. Supported options: squaredError, huber.'): 'squaredError', Param(parent='LinearRegression_529bb0ad1e5e', name='maxBlockSizeInMB', doc='maximum memory in MB for stacking input data into blocks. Data is stacked within partitions. If more than remaining data size in a partition then it is adjusted to the data size. Default 0.0 represents choosing optimal value, depends on specific algorithm. Must be >= 0.'): 0.0, Param(parent='LinearRegression_529bb0ad1e5e', name='maxIter', doc='max number of iterations (>= 0).'): 100, Param(parent='LinearRegression_529bb0ad1e5e', name='predictionCol', doc='prediction column name.'): 'prediction', Param(parent='LinearRegression_529bb0ad1e5e', name='regParam', doc='regularization parameter (>= 0).'): 0.001, Param(parent='LinearRegression_529bb0ad1e5e', name='solver', doc='The solver algorithm for optimization. Supported options: auto, normal, l-bfgs.'): 'auto', Param(parent='LinearRegression_529bb0ad1e5e', name='standardization', doc='whether to standardize the training features before fitting the model.'): True, Param(parent='LinearRegression_529bb0ad1e5e', name='tol', doc='the convergence tolerance for iterative algorithms (>= 0).'): 1e-06}

# %%
lrcvModel.bestModel.intercept
# Out:
# -36.43748711990771

# %%
lrcvModel.bestModel.coefficients
# Out:
# DenseVector([0.4339, 0.0095, -0.1018, 0.6161, -0.0, -0.0037, -0.4163, -0.4289])

# %%
housing_sp.schema.names[:-1] # last one is the target
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# Interpretation:
# - Median Income influences the housing prices.
# - Surprisingly, older houses are more expensive.
# - Houses with less rooms as well - this might be a correction factor to a large influence of AveBedrooms: More rooms increase the housing price as long as there are enough beds/bedrooms. Alternatively, a large number of rooms might indicate a large number of houses used only for the holidays.
# - The popoulation in this area has no influence on the price.
# - Southern and western areas are more expensive than northeastern ones. (This could be a potential influence of LA and SF).

# %% [markdown]
# ### Summary
#
# - There are I/O- and CPU-bound problems
# - Use `threading` for I/O-bound problems, `multiprocessing` for CPU-bound problems
# - Communication between processes is cumbersome
# - For many CPU-bound tasks, there may be implemented solutions.
